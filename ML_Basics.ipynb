# %% [markdown]
# ## Machine Learning Basics

# %% [markdown]
# ### Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.normal(3, 1, 10)
y = 100 - (x + np.random.normal(0, 0.1, 10)) * 3

plt.scatter(x, y)  # Use plt.scatter() to create a scatter plot
plt.show()  # Display the plot
